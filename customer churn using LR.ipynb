# %% [markdown]
# ## Customer churn prdiction using Logistic Regression

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# Imporitn dataset

df = pd.read_csv('datasets/Customer-Churn-Prediction.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
sb.countplot(df['Churn'])
# Out:
# c:\users\crazy\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
Churned = df[df.Churn == 'Yes'].shape[0]
retained = df[df.Churn == 'No'].shape[0]

# %%
# Customer left the company

ch_per = ((Churned /(Churned+retained)) * 100)
ch_per
# Out:
# 26.536987079369588

# %%
# Customer Stayed the company
re_per = ((retained /(Churned+retained)) * 100)
re_per
# Out:
# 73.4630129206304

# %% [markdown]
# ## Let's don some visualization

# %%
print(df['gender'].value_counts())
sb.countplot(x='gender', hue='Churn', data = df)
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
print(df['MultipleLines'].value_counts())
sb.countplot(x='MultipleLines', hue='Churn', data = df)
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
print(df['InternetService'].value_counts())
sb.countplot(x='InternetService', hue='Churn', data = df)
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
print(df['SeniorCitizen'].value_counts())
sb.countplot(x='SeniorCitizen', hue='Churn', data = df)
# Out:
# 0    5900
# 1    1143
# Name: SeniorCitizen, dtype: int64
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# ## Data Preprocessing

# %%
# df.isnull().any()
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162289    32.370865       64.761692
# std         0.368742    24.559231       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# Drop Customer id 
df = df.drop('customerID', axis=1)
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# ### Handle categorical value using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

df
# Out:
# <ipython-input-24-2a8171edc245>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# ...

# %%
# spliting dataset
x = df.drop('Churn',axis=1)
y = df['Churn']

# %%
# scaling
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler().fit_transform(x)

sc_x
# Out:
# array([[-1.00955867, -0.44014635,  1.03453023, ...,  0.39855772,
#         -1.16032292, -0.39860759],
#        [ 0.99053183, -0.44014635, -0.96662231, ...,  1.33486261,
#         -0.25962894, -0.94876238],
#        [ 0.99053183, -0.44014635, -0.96662231, ...,  1.33486261,
#         -0.36266036, -1.64188328],
#        ...,
#        [-1.00955867, -0.44014635,  1.03453023, ...,  0.39855772,
#         -1.1686319 , -0.13968008],
#        [ 0.99053183,  2.27197156,  1.03453023, ...,  1.33486261,
#          0.32033821, -0.31653445],
#        [ 0.99053183, -0.44014635, -0.96662231, ..., -1.47405205,
#          1.35896134,  1.13801338]])

# %%
# spliting to test train

from sklearn.model_selection import train_test_split
xtrain,xtest, ytrain,ytest = train_test_split(sc_x, y, test_size=.25,random_state=20)
xtest
# Out:
# array([[-1.00955867, -0.44014635, -0.96662231, ..., -0.53774716,
#         -1.49102052,  0.61009777],
#        [-1.00955867, -0.44014635,  1.03453023, ...,  0.39855772,
#         -0.15825932,  0.19867306],
#        [-1.00955867, -0.44014635, -0.96662231, ..., -1.47405205,
#          0.78896497, -0.05919545],
#        ...,
#        [-1.00955867, -0.44014635,  1.03453023, ..., -0.53774716,
#          0.35357415, -1.0536042 ],
#        [-1.00955867,  2.27197156,  1.03453023, ...,  1.33486261,
#          0.18905625,  1.19255231],
#        [ 0.99053183, -0.44014635,  1.03453023, ..., -0.53774716,
#         -0.86950844, -0.67606776]])

# %% [markdown]
# ## Model Fit

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred = model.predict(xtest)
pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %% [markdown]
# ## Performance Metrics

# %%
# accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred)
# Out:
# 0.8228279386712095

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(ytest,pred)
# Out:
# array([[1180,  133],
#        [ 179,  269]], dtype=int64)

# %%
# classification report
from sklearn.metrics import classification_report
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1313
#            1       0.67      0.60      0.63       448
#
#     accuracy                           0.82      1761
#    macro avg       0.77      0.75      0.76      1761
# weighted avg       0.82      0.82      0.82      1761

# %% [markdown]
# ## Handle categorical data using Min Max scaler

# %%
# from sklearn.preprocessing import MinMaxScaler

# minmax = MinMaxScaler(feature_range= (0,1))
# for column in df.columns:
#     if df[column].dtype == np.number:
#         continue
#     df[column] = minmax.fit_transform(df[column])

# df
